# %%
import requests
from bs4 import BeautifulSoup
import pandas
import time
import json
import pandas as pd
import re

def change_time(item):
    t=int(item)
    t=time.localtime(t)
    return time.strftime("%Y-%m-%d",t)

# %%
#註記:聽說每個ip爬超過1000則文章就會被中斷

# %%
# articles        | comments        |replies
# -------------------------------------------------------               
# title        N  | id           W  |
# author_name  Y  | comment_id   Y  |
# author_id    Y  | author_name  Y  |
# context      Y  | context      Y  |
# platform_id  N  | post_id      W  |
# post_id      Y  | post_time    Y  |
# post_time    Y  | platfrom_id  N  |
# like_num     Y  | like_num     Y  |
    #haha      Y  |    haha      Y  |
    #anger     Y  |    anger     Y  |
    #love      Y  |    love      Y  |
    #sorry     Y  |    sorry     Y  |
    #wow       Y  |    wow       Y  |
# share_num    Y  |

# ------------------------------------------------------- 
 #comment_count(留言+回覆)
 #display_commnets(留言)
 #如果硬要的話其實也可以將p標籤第一句作為標題
    
#初始url='https://www.facebook.com/pages_reaction_units/more/?page_id=433004610088636&cursor={"card_id":"page_posts_divider","has_next_page":true}&surface=www_pages_home&unit_count=8&fb_dtsg_ag&__user=0&__a=1'
#透過正則表達式抓取網址內容中的cursor，並只擷取有關timeline_cursor的部分
#域名+page_id+timeline_cursor+&surface=www_pages_home&unit_count=8&fb_dtsg_ag&__user=0&__a=1
#unit_count 可以替換

#註記:好像會少最新兩則

# %%
headers={'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Safari/537.36'}
#url='https://www.facebook.com/weather.taiwan/?hc_ref=ARQCAALTgri66IJDHd1vIrLquvP0gMsmfAwC6t9g1fhyVI3yaz1XEiduOIufIIZfBDk&fref=nf&__tn__=kC-R'
url='https://www.facebook.com/CWB.TW/'
resp=requests.get(url,headers=headers)
pattern=r'"entity_id":"\d+"'
page_id=re.search(pattern,resp.text).group()
pattern=r'\d+'
page_id=re.search(pattern,page_id).group()
page_id
# Out:
# '129328600420380'

# %%
data_text=[]
data_time=[]
err_data=[]
data_feedback=[]

# %%
#文章
#url='https://www.facebook.com/pages_reaction_units/more/?page_id=433004610088636&cursor={%22card_id%22:%22page_posts_divider%22,%22has_next_page%22:true}&surface=www_pages_home&unit_count=10&fb_dtsg_ag&__user=0&__a=1'
#url='https://www.facebook.com/pages_reaction_units/more/?page_id=433004610088636&cursor={%22timeline_cursor%22:%22AQHRxd9iiqy86qLrSw_yb_moxoNysqr-e2zPn91UGJv2Be6bTAIzKoDQI5nY49eMcRKk-yl7fjStyO7pH1kPl-Em1ygmVyKQI3r-JmAeItN2VHURii3-m_qJyVgr-QX_9pbZ%22,%22timeline_section_cursor%22:{},%22has_next_page%22:true}&surface=www_pages_home&unit_count=8&fb_dtsg_ag&__user=0&__a=1'
url='https://www.facebook.com/pages_reaction_units/more/?page_id=433004610088636&cursor={%22timeline_cursor%22:"",%22timeline_section_cursor%22:{},%22has_next_page%22:true}&surface=www_pages_home&unit_count=8&fb_dtsg_ag&__user=0&__a=1'


for i in range(1):
    #try:
    session=requests.session()
    resp=session.get(url)
    #----------likenum and share_num-------
    data=json.loads(resp.text.split(';',3)[3])['jsmods']['pre_display_requires']
    dict_for_temp={}#暫時儲存特定post_id的likenum and share_num

    for i in range(0,len(data)):
        try:
            post_id=data[i][3][1]['__bbox']['result']['data']['feedback']['subscription_target_id']
            feedback_id=data[i][3][1]['__bbox']['result']['data']['feedback']['id']
            reaction_dict={}
            reaction_data=data[i][3][1]['__bbox']['result']['data']['feedback']['top_reactions']['edges']
            for j in range(0,len(reaction_data)):
                reaction_type=reaction_data[j]['node']['reaction_type']
                reaction_count=reaction_data[j]['reaction_count']
                reaction_dict[reaction_type]=int(reaction_count)
                #總共六種心情
                share_num=data[i][3][1]['__bbox']['result']['data']['feedback']['share_count']['count']
                reaction_dict['share_num']=share_num
                reaction_dict['feedback_id']=feedback_id
                data_feedback.append(feedback_id)#delete
            dict_for_temp[post_id]=reaction_dict
        except:
            pass
    #-----------post_time,context and post_id-------------
    texts=json.loads(resp.text.split(';',3)[3])['domops'][0][3]['__html']
    soup=BeautifulSoup(texts,'lxml')
    items=soup.find_all('div',class_="_4-u2 _4-u8")
    url_section=soup.find('div',class_="clearfix uiMorePager stat_elem _52jv").a['ajaxify']

    for item in items:

        context=item.find('p').text
        post_time=change_time(item.find('abbr',class_="_5ptz")['data-utime'])
        temp=str(item.find('a',class_="see_more_link"))
        pattern=r'posts/\d+"'
        temp=re.search(pattern,temp).group()
        pattern='\d+'
        post_id=re.search(pattern,temp).group()
        print('post_id:'+post_id)
        print(post_time)
        print(context)
        print(dict_for_temp[post_id])
        data_text.append(context)
        data_time.append(post_time)
        print('--------------------')
    time.sleep(5)
    url='https://www.facebook.com'+url_section+'&fb_dtsg_ag&__user=0&__a=1'
    #except:
    #    err_data.append(item)
    #    print('error')

# %%
article_data=pd.DataFrame()
article_data['context']=data_text
article_data['post_time']=data_time
article_data['author_name']='天氣即時預報'

# %%
data_feedback=list(set(data_feedback))

# %%
#找取其他相關資料，如:feedtargetid
json.loads(resp.text.split(';',3)[3])['jsmods']

# %%
data_con=[]
data_texts=[]
params_0={'__user': '0',
          '__a': '1',
          "doc_id": "2808628465838895",
          'variables':'''{
          "first":50,
          "feedbackID":"",
          "viewOption":"RANKED_UNFILTERED",
          "after":null
         }'''
         }
if 'null' in params_0['variables']:
    params_0['variables']=params_0['variables'].replace('null','None')
test=eval(params_0['variables'])
test['feedbackID']="ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ=="
params_0['variables']=str(test)
params_0['variables']=params_0['variables'].replace('None','null')

#while True:
for i in range(2):
    url='https://www.facebook.com/api/graphql/'
    session=requests.session()
    session.headers['User-Agent']='Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Safari/537.36'
    resp=session.post(url,data=params_0)

    data=json.loads(resp.text)
    time.sleep(5)
    post_id=data['data']['feedback']['id']#post_id
    end_cursor=data['data']['feedback']['display_comments']['page_info']['end_cursor']
    for j in range(0,len(data['data']['feedback']['display_comments']['edges'])):
        try:
            post_time=change_time(data['data']['feedback']['display_comments']['edges'][j]['node']['created_time'])#post_time
            #author_id=data['data']['feedback']['display_comments']['edges'][j]['node']['author']['id']#author_id
            author_name=data['data']['feedback']['display_comments']['edges'][j]['node']['author']['name']#author_name    
            feedback_id=data['data']['feedback']['display_comments']['edges'][j]['node']['feedback']['id']#找取回覆的查詢參數
            comment_id=data['data']['feedback']['display_comments']['edges'][0]['node']['legacy_fbid']
            reaction_dict={}
            reaction_data=data['data']['feedback']['display_comments']['edges'][j]['node']['feedback']['top_reactions']['edges']#心情
            for i in range(0,len(reaction_data)):
                reaction_type=reaction_data[i]['node']['reaction_type']
                reaction_count=reaction_data[i]['reaction_count']
                reaction_dict[reaction_type]=reaction_count
            #共六種心情

            reply_count=data['data']['feedback']['display_comments']['edges'][j]['node']['feedback']['comment_count']['total_count']#回覆數
            context=data['data']['feedback']['display_comments']['edges'][j]['node']['preferred_body']['text']#context
            if reply_count>=1:
                data_con.append(feedback_id)
            data_texts.append(context)
            #print('flatform_id:'+self.name)
            print('post_id:'+post_id)
            print('comment_id:'+comment_id)
            print('post_time:'+post_time)
            #print('author_id:'+author_id)
            print('author_name:'+author_name)
            print('context:'+context)
            print('reply_count:'+str(reply_count))#if reply_count>0:run reply_parse
            print(reaction_dict)
            print('-------------------------------------------------')
        except:
            pass

    if end_cursor ==None:
        break
    else:
        if 'null' in params_0['variables']:
            params_0['variables']=params_0['variables'].replace('null','None')
        test=eval(params_0['variables'])
        test['after']=end_cursor
        params_0['variables']=str(test)
        params_0['variables']=params_0['variables'].replace('None','null')
# Out:
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:范安室
# context:請問冷氣團是全台都冷嗎？周一要前往台中
# reply_count:8
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:Chen Amy
# context:小編之前說冬衣可以收一半起來了
# 我買好整理箱要收的說 🤣🤣🤣
# reply_count:8
# {'LIKE': 1}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:張玉玲
# context:拜託千萬別太冷啊！更不要下雨喔！下星期一.星期二要回.最愛台中放輕鬆.離開恐怖冷漠北部人啊！
# reply_count:4
# {'LIKE': 3, 'HAHA': 3}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:Anna Shao
# context:四月居然有冷氣團，印象中沒遇過
# reply_count:18
# {'LIKE': 33, 'ANGER': 1}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-10
# author_name:陳潔慧
# context:因北方仍有大陸冷高壓帶下東北風之故，今天(9日)台中有稍涼的北風，且雲少天晴中午有27~28度的高溫，但日間均溫大都在24度上下且沒南風並不能算熱，不過隨著高氣壓東移轉東風之故，台中這邊又會位處背風側容易有白天溫高且大氣擴散條件差的現象發生喔！(圖源：CWB)
# reply_count:1
# {'LIKE': 2, 'LOVE': 1}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:Peggy Lee
# context:請問台南星期日會下很大嗎？要出去 🤧
# reply_count:2
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:郭芳菻
# context:請問禮拜六大約晚上下雨還是中午過後就開始下大雨了呢
# reply_count:7
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:劉俊賢
# context:還有冷氣團 會很冷嗎
# reply_count:7
# {'LIKE': 5}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:廖婉鈴
# context:臺中是早晚冷嗎
# reply_count:3
# {'LIKE': 1}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:Liu Juke
# context:今天台南天氣溫暖涼爽還算舒適，謝謝小編早安😀
# reply_count:0
# {'LIKE': 1}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:May Fu
# context:今天早上有点冷了，這篇報導，我也存檔，因為關係着週六日的冷氣團，謝謝小編!
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:Jean WU
# context:讚喔！屏東人感到興奮🤩
# reply_count:0
# {'LIKE': 7, 'HAHA': 2}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:鄧淑玲
# context:哇哇…感謝暖心小編 寫的好清楚 我也看的很仔細！！(馬上應戰)
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:林淑卿
# context:這是什麼天氣？春天了還這麼冷
# 週末下雨真是應景，讓大家別亂趴趴走
# reply_count:0
# {'LIKE': 1, 'HAHA': 1}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:陳松煥
# context:北部何時有太陽可以曬
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:廖麗美
# context:可以不要這樣嗎？我棉被毯子都洗好收好，冬衣都送洗了😰
# reply_count:0
# {'LIKE': 1}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:Yunyun Wu
# context:厚外套就是收不起來的一個概念😂
# reply_count:0
# {'LIKE': 1}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:Shirley Kuo
# context:天氣溜滑梯，家中長輩要注意一下！
# reply_count:0
# {'LIKE': 3}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:江淑琦
# context:還好棉被和厚外套都還沒收😅謝謝辛苦的小編
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:趙艾瑪
# context:厚衣服都收光了😂
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:戴惠萍
# context:收好的冬衣又要拿出來😣😣
# reply_count:0
# {'LIKE': 1, 'SORRY': 1}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:Chao Wei Lo
# context:天氣驟變啊
# reply_count:0
# {'LIKE': 2}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:吳勇達
# context:希望可以涼到端午節。。。
# reply_count:0
# {'LIKE': 3, 'HAHA': 1}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:楊軒畯
# context:謝謝您，感恩。
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:陳絨
# context:氣候變化多端，孩子們要穿長袖薄的 ，不可大意
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:吳紫綺
# context:冬衣都收了又陸續搬出來了😩
# reply_count:0
# {'LIKE': 2}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:劉禹承
# context:久違的四月強冷！
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:Cao Ting
# context:冬天的衣服都已經收完了⋯⋯
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:Li Hsuan Chen
# context:端午沒過別急著收冬衣啊~
# reply_count:0
# {'LIKE': 2}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:蘇如如
# context:居然還有強烈冷氣團😱😱
# reply_count:2
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:Pan Yi Chen
# context:幸好是假日有雨，可以窩在家
# reply_count:0
# {'LIKE': 1}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:周亞運
# context:哭....昨天才收了一堆冬衣外套
# reply_count:1
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:楊楊
# context:還好冬天的衣服沒收進櫃子內
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:謝彩雲
# context:記住端午節過後才能收棉被，端午時節雨紛紛天氣還是會變的
# reply_count:0
# {'LIKE': 6}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:江致賢
# context:可以再多享受涼涼冷冷的天氣了
# reply_count:0
# {'LIKE': 2, 'HAHA': 1}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:Duke Tsai
# context:今年似乎涼比較久~~~
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:Eddie Chen
# context:高山不會在這時候下雪吧？
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:Peigi Tsai
# context:高雄又可以冷了😆✌
# reply_count:1
# {'LIKE': 2, 'ANGER': 1}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:陳頎錄
# context:請問禮拜天中午前會下雨嗎
# reply_count:4
# {'LIKE': 1}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:洪雅萍
# context:又要轉冷涼了，我的鼻炎又剉咧蛋了😫
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:御堂嵐
# context:冷對台南人來說算是還好而已,但就不能接受冷又下雨啊啊啊啊啊啊啊!
# reply_count:0
# {'LIKE': 1}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:Chan Yi Ching
# context:又要變冷了，要注意保暖。
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:王秋蘭
# context:王小樂 北部氣溫驟降，要注意保暖呦！
# reply_count:0
# {'LIKE': 1}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:林聖得
# context:吃完肉粽才可以收棉被0.0
# reply_count:0
# {'LIKE': 3}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:林鈵樺
# context:會不會是疫情，人類停止大型排放，地球在變正常...
# reply_count:0
# {'LIKE': 4}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:Rubio Liu
# context:請問禮拜日屏東阿朗壹雨會很多嗎
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:張雅婷
# context:剛把棉被收起來:(
# reply_count:4
# {'LIKE': 1}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:邱柏錚
# context:鄭正風 週六下午到週日上午會下雨欸🥺🥺🥺
# reply_count:0
# {'LOVE': 1}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:楊星星
# context:星期日屏東楓港雨會大嗎
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908475872541485
# post_time:2020-04-09
# author_name:陳美如
# context:邱俊傑常思為禮拜六下午會下雨🥺
# reply_count:0
# {'SORRY': 2}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Jessie Tsai
# context:翁小慧媽呀，星期日會冷又下雨耶
# reply_count:1
# {'LIKE': 1}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:水晨凱
# context:看來還是再入一桶煤油好了
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Grace Huang
# context:嫈琦竟然有強烈冷氣團!
# reply_count:1
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:黃雯倩
# context:還好厚被沒收
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:郭芳如
# context:請問圖片是最低溫嗎？
# 屆時高雄的最高溫大約落在幾度呢？
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:劉其杰
# context:劉其昕 林宥伸 劉庭余 留意天氣狀況唷
# reply_count:0
# {'LIKE': 2}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:楨心云
# context:可以冷但不要下雨嗎😬
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Will Long
# context:冷涼四月天 🤣🤣🤣
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:謝竹豐
# context:週五/六 天氣穩定
# reply_count:0
# {'LIKE': 2}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:謝彩雲
# context:冷氣團下探11度
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Sam Tsai
# context:都幾月了還在冷，今年果然是中猴年...
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Hua-Ching Wen
# context:時間還久意思是還有變化的可能嗎
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Bea Lee
# context:謝謝小編👍
# 還好我都還沒收冬天的衣物，趁這幾天有大太陽，先拿出來曬曬！！！☀️☀️☀️
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Huang Chien
# context:請問星期六陽明山仰德大道那會下一整天的雨嗎？
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Brian Chu
# context:請問週日高山有可能降雪嗎！謝謝🙏
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Johnny Ho
# context:哇，我冬衣都收起來了說。
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Joey Lai
# context:黃子豪 傻眼 我們要不要吃有湯的東西
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Fan Ya Hsu
# context:真的是春天後母心
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:簡嘉琪
# context:鄒彰億星期六下午會下雨到隔天早上，施肥可能不適合
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Joey Chung
# context:冬被都收了，冏
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:洪苓馨
# context:冬衣都已經收完了!現在又要翻出來囉！
# reply_count:2
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:林蓉
# context:放假想帶小孩去放風都遇雨丫...
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:陳盈螢
# context:好像有個俗諺說端午節才能收冬被？不過人家提醒我今年有閏月，端午節又更慢了😳
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:鄭明秀
# context:去年的四月就蠻熱了
# 想不到今年四月還會冷
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:龍芳
# context:感謝有你相陪
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:曾濟彬
# context:台中禮拜天是中午前下雨嗎？
# reply_count:1
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Pei Yi Cho
# context:請問週末嘉義天氣如何
# reply_count:1
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-10
# author_name:蔡俽語
# context:林建穎是在哈囉 我厚衣服全帶回高雄了……
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:潘麗卿
# context:古人說  春天後母心
# reply_count:1
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:謝伊婷
# context:清明節過後本來應該要準備換季，結果又變濕冷了😅
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:楊乃玟
# context:請問今明兩天宜蘭天氣如何呢？會不會下雨呢～
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Yen Dison
# context:珍惜這清明後 涼涼的日子
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Cherry Song
# context:一直不敢收起棉被😂😅
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Yu Da Chen
# context:請問這次雨多嗎
# reply_count:1
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Sanggye Chen
# context:謝謝提醒，早晚真的都比較涼冷！
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-10
# author_name:Tmac Chen
# context:您好，請問明天台中會下雨嗎?  下雨時間點大概落在哪個時候，謝謝。
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Osiris Su
# context:Alin Su
# 冬天衣服提前準備一下～
# reply_count:2
# {'LIKE': 2}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:謝廷翊
# context: 朱苡瑄變天囉穿暖些
# reply_count:0
# {'LIKE': 1}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:徐亮亮
# context:阿嬤說的是真的鄭小昌
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-10
# author_name:劉鈞豪
# context:新竹週六早上會下雨嗎？？
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:詹治勳
# context:那南投信義鄉是否下雨天。我週六日要去那邊
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Mei-chun  Chen
# context:請問小編，星期六下午～星期日早上南投雨勢會很大嗎？謝謝小編!
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Jennifer Huang
# context:Allen Chuang 😱😱 好像會下雨捏。 要改雨棚區嗎？
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:尤紫盈
# context:蔣孝萱 Pearl Chen 週日大降溫還下雨😨😨😨
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:邱傑
# context:王郁慈 星期天開始冷喔!
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Sherry Chou
# context:北部什麼時候才能有大太陽！好久沒曬到太陽了😭😭
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Faustine I-Lun Chuang
# context:繼續冷下去吧！ 反正從6月起到11月會熱到發瘋  台灣的夏天很長
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:May Yu
# context:➕➕請問合歡山週日何時有可能下雪嗎謝
# reply_count:0
# {'WOW': 1}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:許智翔
# context:請問這週六晚上高雄下雨的機率很大嗎？
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMQ==
# comment_id:2908493435873062
# post_time:2020-04-09
# author_name:Peiting Chao
# context:哇靠。突然想到疫情。本喜歡天冷的我。突然憂國憂民ㄌㄜ
# reply_count:0
# {}
# -------------------------------------------------

# %%
data_reply=[]
for t in ['ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMV8yOTA5MDQ4ODI5MTUwODU2']:
    params_0={'__user': '0',
                  '__a': '1',
                  "doc_id": "2808628465838895",
                  'variables':'''{
                  "first":50,
                  "feedbackID":"",
                  "viewOption":"RANKED_UNFILTERED",
                  "after":null,
                  "UFI2CommentsProvider_commentsKey":null,
                 }'''
                 }
    if 'null' in params_0['variables']:
        params_0['variables']=params_0['variables'].replace('null','None')
    if 'false' in params_0['variables']:
        params_0['variables']=params_0['variables'].replace('false','False')
    test=eval(params_0['variables'])
    test['feedbackID']=t
    params_0['variables']=str(test)
    params_0['variables']=params_0['variables'].replace('None','null')

    #while True:
    for w in range(1):
        url='https://www.facebook.com/api/graphql/'
        session=requests.session()
        session.headers['User-Agent']='Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Safari/537.36'
        resp=session.post(url,data=params_0)

        data=json.loads(resp.text)
        time.sleep(2)
        post_id=data['data']['feedback']['id']#post_id
        end_cursor=data['data']['feedback']['display_comments']['page_info']['end_cursor']
        for j in range(0,len(data['data']['feedback']['display_comments']['edges'])):
            try:
                post_time=change_time(data['data']['feedback']['display_comments']['edges'][j]['node']['created_time'])#post_time
                #author_id=data['data']['feedback']['display_comments']['edges'][j]['node']['author']['id']#author_id
                author_name=data['data']['feedback']['display_comments']['edges'][j]['node']['author']['name']#author_name    
                #data['data']['feedback']['display_comments']['edges'][j]['node']['feedback']['id']#找取回覆的查詢參數
                comment_id=data['data']['feedback']['display_comments']['edges'][0]['node']['legacy_fbid']
                reaction_dict={}
                reaction_data=data['data']['feedback']['display_comments']['edges'][j]['node']['feedback']['top_reactions']['edges']#心情
                for i in range(0,len(reaction_data)):
                    reaction_type=reaction_data[i]['node']['reaction_type']
                    reaction_count=reaction_data[i]['reaction_count']
                    reaction_dict[reaction_type]=reaction_count
                #共六種心情

                reply_count=data['data']['feedback']['display_comments']['edges'][j]['node']['feedback']['comment_count']['total_count']#回覆數
                context=data['data']['feedback']['display_comments']['edges'][j]['node']['preferred_body']['text']#context
                data_reply.append(context)
                #print('flatform_id:'+self.name)
                print('post_id:'+post_id)
                print('comment_id:'+comment_id)
                print('post_time:'+post_time)
                #print('author_id:'+author_id)
                print('author_name:'+author_name)
                print('context:'+context)
                print('reply_count:'+str(reply_count))#if reply_count>0:run reply_parse
                print(reaction_dict)
                print('-------------------------------------------------')
            except:
                pass

        if end_cursor ==None:
            break
        else:
            if 'null' in params_0['variables']:
                params_0['variables']=params_0['variables'].replace('null','None')
            if 'false' in params_0['variables']:
                params_0['variables']=params_0['variables'].replace('false','False')
            test=eval(params_0['variables'])
            test['after']=end_cursor
            test["UFI2CommentsProvider_commentsKey"]=test['feedbackID']
            params_0['variables']=str(test)
            params_0['variables']=params_0['variables'].replace('None','null')
# Out:
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMV8yOTA5MDQ4ODI5MTUwODU2
# comment_id:2913433818712357
# post_time:2020-04-11
# author_name:Eason Shen
# context:周鈺婷 走啊 去哪
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMV8yOTA5MDQ4ODI5MTUwODU2
# comment_id:2913433818712357
# post_time:2020-04-11
# author_name:周鈺婷
# context:歐鈺穗 出去玩ㄌ
# reply_count:0
# {}
# -------------------------------------------------
# post_id:ZmVlZGJhY2s6MjkwODQ2ODE3OTIwODkyMV8yOTA5MDQ4ODI5MTUwODU2
# comment_id:2913433818712357
# post_time:2020-04-09
# author_name:歐鈺穗
# context:Eason Shen
# reply_count:2
# {}
# -------------------------------------------------

# %%
post_id=data['data']['feedback']['display_comments']['edges'][0]['node']['legacy_token']#.split('_')[0]
post_id
# Out:
# '2908468179208921_2908829492506123'

# %%
#流程:
#1.從首頁網址獲取page_id作為查詢文章的網址中的參數之一，並利用該網址獲取ㄧjson檔，裡面有一部分為script標籤中的內容(即為文章內容，如:post_time,author_id,author_name,context)
#2.除了利用上述網址獲取文章內容，也可以獲取like_num,share_num,feeback_id(作為獲取某文章下的留言的查詢參數) and post_id
#2.1 #註記:like_num等資料是需要以post_id作為key來獲取的
#----------------以上為文章部分---------------
#3.利用得到的feedback_id以及一些參數作為post給留言查詢網址的查詢參數(重要參數如_user,_a,feedback_id,view_option(排序方式),after(指向下一篇文章的參數))
#4.利用上述網址或的的json檔來解析留言資料表所需的內容，基本上與文章的解析差不多
#----------------以上為留言部分----------------
#5. #註記:回覆部分跟留言部分一模一樣只是改掉了feedback_id而已
#----------------以上為回覆部分----------------
#因為我們需要替換feedback_id與after，所以在爬取的參數variables進行替換但是該參數是以字串作為傳遞的型態，單純使用正規表達式太麻煩，所以我改成替換時需要暫時轉成字典型態(eval())，
#但是裡面會有null的出現，需要先將其替換成None，替換完feedback_id或after時，需要再將variables的型態轉為字串並且以None替換回去null

# %%
import pandas as pd
data=pd.read_csv('tutorial/article_ettoday.csv')

# %%
data
# Out:
#     anger_num        author_id    author_name        comment_id  \
# 0         NaN  100000667791375            范安室  2908475872541485
# 1         NaN  100000138110237       Chen Amy  2908539849201754
# 2         NaN  100023559169189            張玉玲  2908471202541952
# 3         1.0  100011199960983      Anna Shao  2908512175871188
# 4         1.0  100000116677212            陳潔慧  2909840275738378
# 5         1.0  100002311894503      Peggy Lee  2908470329208706
# 6         1.0  100012557554243            郭芳菻  2908483642540708
# 7         1.0  100013576564225            劉俊賢  2908471349208604
# 8         1.0  100007819485237            廖婉鈴  2908477392541333
# 9         1.0  100001254616304       Liu Juke  2908589672530105
# 10        1.0  100000174900790         May Fu  2908551262533946
# 11        1.0  100009208451988        Jean WU  2908628732526199
# 12        1.0  100000120027543            鄧淑玲  2908771815845224
# 13        1.0  100000315400763            林淑卿  2908510092538063
# 14        1.0  100000018794195            陳松煥  2908512965871109
# 15        1.0  100003354934857            廖麗美  2908520705870335
# 16        1.0  100003809871380      Yunyun Wu  2908696195852786
# 17        1.0  100002499444146    Shirley Kuo  2908549732534099
# 18        1.0  100000224392445            江淑琦  2908529722536100
# 19        1.0       1774171649            趙艾瑪  2908542859201453
# 20        1.0  100011713966063            戴惠萍  2908476119208127
# 21        1.0  100000090131902    Chao Wei Lo  2908490879206651
# 22        1.0  100000250315498            吳勇達  2908621765860229
# 23        1.0  100000140962550            楊軒畯  2908526675869738
# 24        1.0  100007424685080             陳絨  2909164742472598
# 25        1.0  100000163298447            吳紫綺  2908471662541906
# 26        1.0  100002147952865            劉禹承  2908549569200782
# 27        1.0  100004892383309       Cao Ting  2908678579187881
# 28        1.0       1010981364  Li Hsuan Chen  2908507079205031
# 29        1.0  100000179113433            蘇如如  2908626842526388
# 30        1.0  100000260605740    Pan Yi Chen  2908523639203375
# 31        1.0       1080430728            周亞運  2908559099199829
# 32        1.0  100001089436386             楊楊  2908664112522661
# 33        1.0  100004574739725            謝彩雲  2908620322527040
# 34        1.0  100000137868226            江致賢  2908491032539969
# 35        1.0        749094328      Duke Tsai  2908504825871923
# 36        1.0  100000072115445     Peigi Tsai  2908483785874027
# 37        1.0       1801424910     Eddie Chen  2908484992540573
# 38        1.0  100023208376288            陳頎錄  2908515922537480
# 39        1.0  100001664933049            洪雅萍  2909393455783060
# 40        1.0  100000595773210            蕭黒輪  2908526449203094
# 41        1.0  100002404281348  Chan Yi Ching  2908667542522318
# 42        1.0  100003529969297            王秋蘭  2908482299207509
# 43        1.0  100001358672790            林聖得  2908570872531985
# 44        1.0  100000387116226            林鈵樺  2908571199198619
# 45        1.0  100002871595503      Rubio Liu  2908568605865545
# 46        1.0       1549997159            張雅婷  2908473085875097
# 47        1.0       1790210177            邱柏錚  2908672469188492
# 48        1.0  100028260947435            楊星星  2908907485831657
# 49        1.0  100000485953225            陳美如  2908568119198927
#
#                                               context  haha_num  like_num  \
# 0                                 請問冷氣團是全台都冷嗎？周一要前往台中       NaN       NaN
# 1                     小編之前說冬衣可以收一半起來了\n我買好整理箱要收的說 🤣🤣🤣       NaN       1.0
# 2      拜託千萬別太冷啊！更不要下雨喔！下星期一.星期二要回.最愛台中放輕鬆.離開恐怖冷漠北部人啊！       3.0       3.0
# 3                                     四月居然有冷氣團，印象中沒遇過       3.0      33.0
# 4   因北方仍有大陸冷高壓帶下東北風之故，今天(9日)台中有稍涼的北風，且雲少天晴中午有27~28...       3.0       2.0
# 5                                  請問台南星期日會下很大嗎？要出去 🤧       3.0       2.0
# 6                           請問禮拜六大約晚上下雨還是中午過後就開始下大雨了呢       3.0       2.0
# 7                                          還有冷氣團 會很冷嗎       3.0       5.0
# 8                                             臺中是早晚冷嗎       3.0       1.0
# 9                              今天台南天氣溫暖涼爽還算舒適，謝謝小編早安😀       3.0       1.0
# 10              今天早上有点冷了，這篇報導，我也存檔，因為關係着週六日的冷氣團，謝謝小編!       3.0       1.0
# 11                                        讚喔！屏東人感到興奮🤩       2.0       7.0
# 12                    哇哇…感謝暖心小編 寫的好清楚 我也看的很仔細！！(馬上應戰)       2.0       7.0
# 13                  這是什麼天氣？春天了還這麼冷\n週末下雨真是應景，讓大家別亂趴趴走       1.0       1.0
# 14                                         北部何時有太陽可以曬       1.0       1.0
# 15                         可以不要這樣嗎？我棉被毯子都洗好收好，冬衣都送洗了😰       1.0       1.0
# 16                                    厚外套就是收不起來的一個概念😂       1.0       1.0
# 17                                   天氣溜滑梯，家中長輩要注意一下！       1.0       3.0
# 18                               還好棉被和厚外套都還沒收😅謝謝辛苦的小編       1.0       3.0
# 19                                           厚衣服都收光了😂       1.0       3.0
# 20                                       收好的冬衣又要拿出來😣😣       1.0       1.0
# 21                                              天氣驟變啊       1.0       2.0
# 22                                       希望可以涼到端午節。。。       1.0       3.0
# 23                                            謝謝您，感恩。       1.0       3.0
# 24                             氣候變化多端，孩子們要穿長袖薄的 ，不可大意       1.0       3.0
# 25                                      冬衣都收了又陸續搬出來了😩       1.0       2.0
# 26                                           久違的四月強冷！       1.0       2.0
# 27                                      冬天的衣服都已經收完了⋯⋯       1.0       2.0
# 28                                       端午沒過別急著收冬衣啊~       1.0       2.0
# 29                                        居然還有強烈冷氣團😱😱       1.0       2.0
# 30                                      幸好是假日有雨，可以窩在家       1.0       1.0
# 31                                   哭....昨天才收了一堆冬衣外套       1.0       1.0
# 32                                      還好冬天的衣服沒收進櫃子內       1.0       1.0
# 33                        記住端午節過後才能收棉被，端午時節雨紛紛天氣還是會變的       1.0       6.0
# 34                                     可以再多享受涼涼冷冷的天氣了       1.0       2.0
# 35                                        今年似乎涼比較久~~~       1.0       2.0
# 36                                          高雄又可以冷了😆✌       1.0       2.0
# 37                                       高山不會在這時候下雪吧？       1.0       2.0
# 38                                       請問禮拜天中午前會下雨嗎       1.0       1.0
# 39                                  又要轉冷涼了，我的鼻炎又剉咧蛋了😫       1.0       1.0
# 40                   冷對台南人來說算是還好而已,但就不能接受冷又下雨啊啊啊啊啊啊啊!       1.0       1.0
# 41                                       又要變冷了，要注意保暖。       1.0       1.0
# 42                                 王小樂 北部氣溫驟降，要注意保暖呦！       1.0       1.0
# 43                                      吃完肉粽才可以收棉被0.0       1.0       3.0
# 44                          會不會是疫情，人類停止大型排放，地球在變正常...       1.0       4.0
# 45                                    請問禮拜日屏東阿朗壹雨會很多嗎       1.0       4.0
# 46                                          剛把棉被收起來:(       1.0       1.0
# 47                               鄭正風 週六下午到週日上午會下雨欸🥺🥺🥺       1.0       1.0
# 48                                        星期日屏東楓港雨會大嗎       1.0       1.0
# 49                                    邱俊傑常思為禮拜六下午會下雨🥺       1.0       1.0
#
#     love_num platform_id           post_id   post_time  sorry_num  wow_num
# 0        NaN    facebook  2908468179208921  2020-04-09        NaN      NaN
# 1        NaN    facebook  2908468179208921  2020-04-09        NaN      NaN
# 2        NaN    facebook  2908468179208921  2020-04-09        NaN      NaN
# 3        NaN    facebook  2908468179208921  2020-04-09        NaN      NaN
# 4        1.0    facebook  2908468179208921  2020-04-10        NaN      NaN
# 5        1.0    facebook  2908468179208921  2020-04-09        NaN      NaN
# 6        1.0    facebook  2908468179208921  2020-04-09        NaN      NaN
# 7        1.0    facebook  2908468179208921  2020-04-09        NaN      NaN
# 8        1.0    facebook  2908468179208921  2020-04-09        NaN      NaN
# 9        1.0    facebook  2908468179208921  2020-04-09        NaN      NaN
# 10       1.0    facebook  2908468179208921  2020-04-09        NaN      NaN
# 11       1.0    facebook  2908468179208921  2020-04-09        NaN      NaN
# 12       1.0    facebook  2908468179208921  2020-04-09        NaN      NaN
# 13       1.0    facebook  2908468179208921  2020-04-09        NaN      NaN
# 14       1.0    facebook  2908468179208921  2020-04-09        NaN      NaN
# 15       1.0    facebook  2908468179208921  2020-04-09        NaN      NaN
# 16       1.0    facebook  2908468179208921  2020-04-09        NaN      NaN
# 17       1.0    facebook  2908468179208921  2020-04-09        NaN      NaN
# 18       1.0    facebook  2908468179208921  2020-04-09        NaN      NaN
# 19       1.0    facebook  2908468179208921  2020-04-09        NaN      NaN
# 20       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 21       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 22       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 23       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 24       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 25       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 26       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 27       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 28       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 29       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 30       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 31       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 32       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 33       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 34       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 35       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 36       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 37       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 38       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 39       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 40       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 41       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 42       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 43       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 44       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 45       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 46       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 47       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 48       1.0    facebook  2908468179208921  2020-04-09        1.0      NaN
# 49       1.0    facebook  2908468179208921  2020-04-09        2.0      NaN
